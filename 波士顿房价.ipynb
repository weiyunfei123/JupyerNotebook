# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
boston_housing=tf.keras.datasets.boston_housing
(train_x,train_y),(test_x,test_y)=boston_housing.load_data()

# %%
print("Training set:",len(train_x))
print("Testing set:",len(test_x))
# Out:
# Training set: 404
# Testing set: 102

# %%
(train_x,train_y),(test_x,text_y)=boston_housing.load_data(test_split=0)

# %%
print("Training set:",len(train_x))
print("Testing set:",len(test_x))
# Out:
# Training set: 506
# Testing set: 0

# %%
type(train_x)
type(train_y)
# Out:
# numpy.ndarray

# %%
print(train_x.ndim)
print(train_y.ndim)
# Out:
# 2
# 1

# %%
print(train_x.shape)
print(train_y.shape)
# Out:
# (506, 13)
# (506,)

# %%
print(train_x[0:5])#输出前五行数据
# Out:
# [[1.23247e+00 0.00000e+00 8.14000e+00 0.00000e+00 5.38000e-01 6.14200e+00
#   9.17000e+01 3.97690e+00 4.00000e+00 3.07000e+02 2.10000e+01 3.96900e+02
#   1.87200e+01]
#  [2.17700e-02 8.25000e+01 2.03000e+00 0.00000e+00 4.15000e-01 7.61000e+00
#   1.57000e+01 6.27000e+00 2.00000e+00 3.48000e+02 1.47000e+01 3.95380e+02
#   3.11000e+00]
#  [4.89822e+00 0.00000e+00 1.81000e+01 0.00000e+00 6.31000e-01 4.97000e+00
#   1.00000e+02 1.33250e+00 2.40000e+01 6.66000e+02 2.02000e+01 3.75520e+02
#   3.26000e+00]
#  [3.96100e-02 0.00000e+00 5.19000e+00 0.00000e+00 5.15000e-01 6.03700e+00
#   3.45000e+01 5.98530e+00 5.00000e+00 2.24000e+02 2.02000e+01 3.96900e+02
#   8.01000e+00]
#  [3.69311e+00 0.00000e+00 1.81000e+01 0.00000e+00 7.13000e-01 6.37600e+00
#   8.84000e+01 2.56710e+00 2.40000e+01 6.66000e+02 2.02000e+01 3.91430e+02
#   1.46500e+01]]

# %%
print(train_x[0:5,5])#输出前5行第6列数
# Out:
# [6.142 7.61  4.97  6.037 6.376]

# %%
#print(train_y)#输出所有train_y的值

# %% [markdown]
# #可视化

# %%
plt.figure(figsize=(5,5)) 
plt.scatter(train_x[:,5],train_y)#平均房间数与房价之间的关系 
plt.xlabel("Room") 
plt.ylabel("Price($1000)") 
plt.title("5.Room-Price") 
plt.show()#不显示文本,只显示图像

# %%
#'''
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plot

boston_housing=tf.keras.datasets.boston_housing
(train_x,train_y),(test_x,test_y)=boston_housing.load_data(test_split=0)

#plt.rcParams["font.sans-serif"]=["SimHei"]
#plt.rcParams["axes.unicode_minus"]=False

titles=["CRIM","ZN","INDUS","CHAS","NOX","ROOM","AGE","DIS","RAD","TAX","PTRATIO","B","LSTAT","MEDV-1000"]
plt.figure(figsize=(12,12))

for i in range(13):
    plt.subplot(4,4,i+1)
    plt.scatter(train_x[:,i],train_y)
    plt.xlabel(titles[i])
    plt.ylabel("Price-1000")
    plt.title(str(i+1)+"."+titles[i]+"-Price")
    
plt.tight_layout()
plt.suptitle("各个属性与房价之间的关系",x=0.5,y=1.02,fontsize=20)
plt.show()
#'''
